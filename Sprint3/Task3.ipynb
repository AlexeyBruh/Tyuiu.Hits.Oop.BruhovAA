// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта: "Управление персоналом"</h2>
//
// ----
//
// ### Вариант задания № 3

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Employee в C#, который будет представлять информацию о
// сотрудниках компании. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
// Требования к базовому классу Employee:
// • Атрибуты: Имя (Name), Возраст (Age), Зарплата (Salary).
// • Методы:
// o GetInfo(): метод для получения информации о сотруднике в виде
// строки.
// o Work(): метод для вывода сообщения о выполнении рабочих
// обязанностей.
// o TakeVacation(): метод для вывода сообщения о взятии отпуска.
// Требования к производным классам:
// 1. Менеджер (Manager): Должен содержать дополнительные атрибуты, такие
// как Количество подчиненных (SubordinatesCount). Метод Work() должен быть
// переопределен для добавления информации о управлении командой.
// 2. Разработчик (Developer): Должен содержать дополнительные атрибуты,
// такие как Специализация (Specialization). Метод TakeVacation() должен быть
// переопределен для добавления информации о необходимости согласования
// отпуска с проектными сроками.
// 3. Дизайнер (Designer) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Стиль дизайна (DesignStyle).
// Метод Work() должен быть переопределен для добавления информации о
// работе над дизайн-проектами.
//
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте полиморфизм с перекрытием и прегегрузкой методов, а также generic классы

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;

public class Employee
{
    // Атрибуты
    public string Name { get; set; }
    public int Age { get; set; }
    public decimal Salary { get; set; }

    // Конструктор
    public Employee(string name, int age, decimal salary)
    {
        Name = name;
        Age = age;
        Salary = salary;
    }

    // Методы
    public virtual string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, Зарплата: {Salary}";
    }
    public virtual string GetInfo(bool inf)
    {
        if (inf)
        {
            return "Сотрудник работает";
        }
        else
        {
            return "Сотрудник уволен";
        }
    }

    public virtual void Work()
    {
        Console.WriteLine($"{Name} выполняет свои рабочие обязанности.");
    }

    public virtual void TakeVacation()
    {
        Console.WriteLine($"{Name} взял отпуск.");
    }
}

public class Manager : Employee
{
    // Дополнительный атрибут
    public int SubordinatesCount { get; set; }

    // Конструктор
    public Manager(string name, int age, decimal salary, int subordinatesCount)
        : base(name, age, salary)
    {
        SubordinatesCount = subordinatesCount;
    }

    // Переопределение метода Work
    public override void Work()
    {
        Console.WriteLine($"{Name} управляет командой из {SubordinatesCount} подчиненных.");
    }
}

public class Developer : Employee
{
    // Дополнительный атрибут
    public string Specialization { get; set; }

    // Конструктор
    public Developer(string name, int age, decimal salary, string specialization)
        : base(name, age, salary)
    {
        Specialization = specialization;
    }

    // Переопределение метода TakeVacation
    public override void TakeVacation()
    {
        Console.WriteLine($"{Name} взял отпуск, необходимо согласовать с проектными сроками.");
    }
}

public interface IDesigner //Интерфейс
{
    void EndHoliday();
}

public class Designer : Employee, IDesigner //Множественное наследование
{
    // Дополнительный атрибут
    public string DesignStyle { get; set; }

    // Конструктор
    public Designer(string name, int age, decimal salary, string designStyle)
        : base(name, age, salary)
    {
        DesignStyle = designStyle;
    }

    public void EndHoliday()
    {
        Console.WriteLine("Отпуск заканичвается через неделю");
    }

    public void EndHoliday(string time) //Перегрузка
    {
        Console.WriteLine($"Отпуск заканичвается через {time}");
    }

    // Переопределение метода Work
    public override void Work()
    {
        Console.WriteLine($"{Name} работает над дизайн-проектами в стиле {DesignStyle}.");
    }

}

public class Intern : Designer //Сложное наследование
{
    public int Time {get; set;}//Дополнительный атрибут
    
    public Intern (string name, int age, decimal salary, string designStyle, int time)
        : base(name, age, salary, designStyle)
        {
            Time = time;
        }

    public void Raising() //Дополнительный метод
    {
        Console.WriteLine($"До повышения осталось {Time} дней");
    }
    public void Raising(bool usl) // Перегрузка
    {
        if (usl)
        {
            Console.WriteLine("Повышение будет");
        }
        else
        {
            Console.WriteLine("Повышения не будет");
        }
    }
}
public class EmployeeCollection<T> where T : Employee // Generic класс
{
    private List<T> _employees = new List<T>();

    public void Add(T em)
    {
        _employees.Add(em);
    }

    public void Remove(T em)
    {
        _employees.Remove(em);
    }
    public void DisplayEmployees()
    {
        foreach (var emp in _employees)
        {
            Console.WriteLine(emp.GetInfo());
        }
    }
}

var manager = new Manager("Иван", 35, 80000, 5);
var developer = new Developer("Анна", 28, 60000, "Backend");
var designer = new Designer("Светлана", 30, 70000, "Минимализм");
var intern = new Intern("Вова", 22, 30000, "Урбан", 14);

Console.WriteLine(manager.GetInfo());
manager.Work();
manager.TakeVacation();

Console.WriteLine();

Console.WriteLine(developer.GetInfo());
developer.Work();
developer.TakeVacation();

Console.WriteLine();

Console.WriteLine(designer.GetInfo());
designer.Work();
designer.TakeVacation();
designer.EndHoliday();

Console.WriteLine();

Console.WriteLine(intern.GetInfo());
intern.Work();
intern.Raising();
intern.Raising(true);

Console.WriteLine();

List<Employee> emp = new List<Employee> //Полиморфизм
{
    new Designer("Светлана", 30, 70000, "Минимализм"),
    new Intern("Вова", 22, 30000, "Урбан", 14)
};

foreach (var em in emp)
{
    Console.WriteLine(em.GetInfo(true));
}

Console.WriteLine();

EmployeeCollection<Employee> empl = new EmployeeCollection<Employee>(); // Реализация Generic класса

empl.Add(new Manager("Иван", 35, 80000, 5));
empl.Add(new Developer("Анна", 28, 60000, "Backend"));

empl.DisplayEmployees();
// Out:
// Имя: Иван, Возраст: 35, Зарплата: 80000
// Иван управляет командой из 5 подчиненных.
// Иван взял отпуск.
//
// Имя: Анна, Возраст: 28, Зарплата: 60000
// Анна выполняет свои рабочие обязанности.
// Анна взял отпуск, необходимо согласовать с проектными сроками.
//
// Имя: Светлана, Возраст: 30, Зарплата: 70000
// Светлана работает над дизайн-проектами в стиле Минимализм.
// Светлана взял отпуск.
// Отпуск заканичвается через неделю
//
// Имя: Вова, Возраст: 22, Зарплата: 30000
// Вова работает над дизайн-проектами в стиле Урбан.
// До повышения осталось 14 дней
// Повышение будет
//
// Сотрудник работает
// Сотрудник работает
//
// Имя: Иван, Возраст: 35, Зарплата: 80000
// Имя: Анна, Возраст: 28, Зарплата: 60000
